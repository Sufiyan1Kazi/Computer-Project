# %%
import math

operation = 0
while operation != 7:
    operation = int(input("Chose the operation to be implied.\nEnter:1 for Addition\nEnter:2 for Subtraction\nEnter:3 for Multiplication\nEnter:4 for Division\nEnter:5 for Second power\nEnter:6 for Square root\nEnter:7 for Exit\n"))
    if operation == 5 or operation == 6 :
        num = int(input("Enter the Number: "))
    elif operation == 1 or operation == 2 or operation == 3 or operation == 4:
        num1 = int(input("Enter the first number: "))
        num2 = int(input("Enter the second number: "))
    elif operation == 7:
        print("Goodbye")  
    else:
        print("Invalid Input")
        
    while operation != 7:
        if operation == 1:
            print("The sum of the two number is: ",num1 + num2)
            break
        elif operation == 2:
            print("The substraction of the two number is: ",num1 - num2)
            break
        elif operation == 3:
            print("The product of the two number is: ",num1 * num2)
            break
        elif operation == 4:
            print("The division of the two number is: ",num1 / num2)
            break
        elif operation == 5:
            print("The second power of the number is: ",num ** 2)
            break
        elif operation == 6:
            print("The square root of the number is: ",math.sqrt(num))
            break
# Out:
# Chose the operation to be implied.
# Enter:1 for Addition
# Enter:2 for Subtraction
# Enter:3 for Multiplication
# Enter:4 for Division
# Enter:5 for Second power
# Enter:6 for Square root
# Enter:7 for Exit
# 1
# Enter the first number: 1
# Enter the second number: 2
# The sum of the two number is:  3
# Chose the operation to be implied.
# Enter:1 for Addition
# Enter:2 for Subtraction
# Enter:3 for Multiplication
# Enter:4 for Division
# Enter:5 for Second power
# Enter:6 for Square root
# Enter:7 for Exit
# 2
# Enter the first number: 2
# Enter the second number: 1
# The substraction of the two number is:  1
# Chose the operation to be implied.
# Enter:1 for Addition
# Enter:2 for Subtraction
# Enter:3 for Multiplication
# Enter:4 for Division
# Enter:5 for Second power
# Enter:6 for Square root
# Enter:7 for Exit
# 3
# Enter the first number: 13
# Enter the second number: 12
# The product of the two number is:  156
# Chose the operation to be implied.
# Enter:1 for Addition
# Enter:2 for Subtraction
# Enter:3 for Multiplication
# Enter:4 for Division
# Enter:5 for Second power
# Enter:6 for Square root
# Enter:7 for Exit
# 4
# Enter the first number: 50
# Enter the second number: 10
# The division of the two number is:  5.0
# Chose the operation to be implied.
# Enter:1 for Addition
# Enter:2 for Subtraction
# Enter:3 for Multiplication
# Enter:4 for Division
# Enter:5 for Second power
# Enter:6 for Square root
# Enter:7 for Exit
# 5
# Enter the Number: 123456
# The second power of the number is:  15241383936
# Chose the operation to be implied.
# Enter:1 for Addition
# Enter:2 for Subtraction
# Enter:3 for Multiplication
# Enter:4 for Division
# Enter:5 for Second power
# Enter:6 for Square root
# Enter:7 for Exit
# 6
# Enter the Number: 5
# The square root of the number is:  2.23606797749979
# Chose the operation to be implied.
# Enter:1 for Addition
# Enter:2 for Subtraction
# Enter:3 for Multiplication
# Enter:4 for Division
# Enter:5 for Second power
# Enter:6 for Square root
# Enter:7 for Exit
# 7
# Goodbye
